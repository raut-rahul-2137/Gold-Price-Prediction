# %% [markdown]
# <a href="https://colab.research.google.com/github/raut-rahul-2137/Gold-Price-Prediction/blob/main/gold_price_prediction_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error
import tensorflow as tf
from keras import Model
from keras.layers import Input ,Dense,Dropout
from keras.layers import LSTM

# %%
df =pd.read_csv('/content/drive/MyDrive/Colab data/Gold Price (2013-2023).csv')

# %%
df.head()
# Out:
#          Date     Price      Open      High       Low     Vol. Change %
# 0  12/30/2022  1,826.20  1,821.80  1,832.40  1,819.80  107.50K    0.01%
# 1  12/29/2022  1,826.00  1,812.30  1,827.30  1,811.20  105.99K    0.56%
# 2  12/28/2022  1,815.80  1,822.40  1,822.80  1,804.20  118.08K   -0.40%
# 3  12/27/2022  1,823.10  1,808.20  1,841.90  1,808.00  159.62K    0.74%
# 4  12/26/2022  1,809.70  1,805.80  1,811.95  1,805.55      NaN    0.30%

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2583 entries, 0 to 2582
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      2583 non-null   object
#  1   Price     2583 non-null   object
#  2   Open      2583 non-null   object
#  3   High      2583 non-null   object
#  4   Low       2583 non-null   object
#  5   Vol.      2578 non-null   object
#  6   Change %  2583 non-null   object
# dtypes: object(7)
# memory usage: 141.4+ KB

# %%
df.columns
# Out:
# Index(['Date', 'Price', 'Open', 'High', 'Low', 'Vol.', 'Change %'], dtype='object')

# %% [markdown]
# ** Data preparation**

# %%
df.drop(['Vol.','Change %'] ,axis = 1,inplace=True)

# %%
df.head()
# Out:
#          Date     Price      Open      High       Low
# 0  12/30/2022  1,826.20  1,821.80  1,832.40  1,819.80
# 1  12/29/2022  1,826.00  1,812.30  1,827.30  1,811.20
# 2  12/28/2022  1,815.80  1,822.40  1,822.80  1,804.20
# 3  12/27/2022  1,823.10  1,808.20  1,841.90  1,808.00
# 4  12/26/2022  1,809.70  1,805.80  1,811.95  1,805.55

# %% [markdown]
# now converting date column as datatime data type

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values(by='Date', ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
NumCols = df.columns.drop(['Date'])
df[NumCols] = df[NumCols].replace({',': ''}, regex=True)
df[NumCols] = df[NumCols].astype('float64')

# %%
df.head()
# Out:
#         Date   Price    Open    High     Low
# 0 2013-01-02  1689.9  1675.8  1695.0  1672.1
# 1 2013-01-03  1675.6  1688.0  1689.3  1664.3
# 2 2013-01-04  1649.9  1664.4  1664.4  1630.0
# 3 2013-01-07  1647.2  1657.3  1663.8  1645.3
# 4 2013-01-08  1663.2  1651.5  1662.6  1648.8

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Date     0
# Price    0
# Open     0
# High     0
# Low      0
# dtype: int64

# %% [markdown]
# # Visualizing the gold history

# %%
fig = px.line(y=df.Price, x=df.Date)
fig.update_traces(line_color='black')
fig.update_layout(xaxis_title="Date",
                  yaxis_title="Scaled Price",
                  title={'text': "Gold Price History Data", 'y':0.95, 'x':0.5, 'xanchor':'center', 'yanchor':'top'},
                  plot_bgcolor='rgba(255,223,0,0.8)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="01ab090a-c0d8-4ac3-bfd2-54194c6aa70a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01ab090a-c0d8-4ac3-bfd2-54194c6aa70a")) {                    Plotly.newPlot(                        "01ab090a-c0d8-4ac3-bfd2-54194c6aa70a",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":
013-06-19T00:00:00","2013-06-20T00:00:00","2013-06-21T00:00:00","2013-06-24T00:00:00","2013-06-25T00:00:00","2013-06-26T00:00:00","2013-06-27T00:00:00","2013-06-28T00:00:00","2013-07-01T00:00:00","2013-07-02T00:00:00","2013-07-03T00:00:00","2013-07-04T00:00:00","2013-07-05T00:00:00","2013-07-08T00:00:00","2013-07-09T00:00:00","2013-07-10T00:00:00","2013-07-11T00:00:00","2013-07-12T00:00:00","2013-07-15T00:00:00","2013-07-16T00:00:00","2013-07-17T00:00:00","2013-07-18T00:00:00","2013-07-19T00:00:00","2013-07-22T00:00:00","2013-07-23T00:00:00","2013-07-24T00:00:00","2013-07-25T00:00:00","20 ...

# %%
test_size = df[df.Date.dt.year==2022].shape[0]
test_size
# Out:
# 260

# %%
plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'yellow'
plt.rc('axes',edgecolor='white')
plt.plot(df.Date[:-test_size], df.Price[:-test_size], color='black', lw=2)
plt.plot(df.Date[-test_size:], df.Price[-test_size:], color='blue', lw=2)
plt.title('Gold Price Training and Test Sets', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.legend(['Training set', 'Test set'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()

# %%
scaler = MinMaxScaler()
scaler.fit(df.Price.values.reshape(-1,1))
# Out:
# MinMaxScaler()

# %%
window_size = 60

# %%
train_data = df.Price[:-test_size]
train_data = scaler.transform(train_data.values.reshape(-1,1))

# %%
X_train = []
y_train = []

for i in range(window_size, len(train_data)):
    X_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

# %%
test_data = df.Price[-test_size-60:]
test_data = scaler.transform(test_data.values.reshape(-1,1))

# %%
X_test = []
y_test = []

for i in range(window_size, len(test_data)):
    X_test.append(test_data[i-60:i, 0])
    y_test.append(test_data[i, 0])

# %%
X_train = np.array(X_train)
X_test  = np.array(X_test)
y_train = np.array(y_train)
y_test  = np.array(y_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test  = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
y_train = np.reshape(y_train, (-1,1))
y_test  = np.reshape(y_test, (-1,1))

# %%
print('X_train Shape: ', X_train.shape)
print('y_train Shape: ', y_train.shape)
print('X_test Shape:  ', X_test.shape)
print('y_test Shape:  ', y_test.shape)
# Out:
# X_train Shape:  (2263, 60, 1)
# y_train Shape:  (2263, 1)
# X_test Shape:   (260, 60, 1)
# y_test Shape:   (260, 1)

# %%
def define_model():
    input1 = Input(shape=(window_size,1))
    x = LSTM(units = 64, return_sequences=True)(input1)
    x = Dropout(0.2)(x)
    x = LSTM(units = 64, return_sequences=True)(x)
    x = Dropout(0.2)(x)
    x = LSTM(units = 64)(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation='softmax')(x)
    dnn_output = Dense(1)(x)

    model = Model(inputs=input1, outputs=[dnn_output])
    model.compile(loss='mean_squared_error', optimizer='Nadam')
    model.summary()

    return model

# %%
model = define_model()
history = model.fit(X_train, y_train, epochs=150, batch_size=32, validation_split=0.1, verbose=1)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 60, 1)]           0
#
#  lstm (LSTM)                 (None, 60, 64)            16896
#
#  dropout (Dropout)           (None, 60, 64)            0
#
#  lstm_1 (LSTM)               (None, 60, 64)            33024
#
#  dropout_1 (Dropout)         (None, 60, 64)            0
#
#  lstm_2 (LSTM)               (None, 64)                33024
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 85057 (332.25 KB)
# Trainable params: 85057 (332.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/150
# 64/64 [==============================] - 18s 162ms/step - loss: 0.0392 - val_loss: 0.0830
# Epoch 2/150
# 64/64 [==============================] - 6s 94ms/step - loss: 0.0115 - val_loss: 0.0378
# Epoch 3/150
# 64/64 [==============================] - 8s 127ms/step - loss: 0.0070 - val_loss: 0.0163
# Epoch 4/150
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0046 - val_loss: 0.0063
# Epoch 5/150
# 64/64 [==============================] - 8s 127ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 6/150
# 64/64 [==============================] - 6s 94ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 7/150
# 64/64 [==============================] - 8s 128ms/step - loss: 0.0019 - val_loss: 0.0034
# Epoch 8/150
# 64/64 [==============================] - 6s 94ms/step - loss: 0.0017 - val_loss: 0.0049
# Epoch 9/150
# 64/64 [==============================] - 8s 122ms/step - loss: 0.0014 - val_loss: 0.0065
# Epoch 10/150
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 11/150
# 64/64 [==============================] - 10s 158ms/step - loss: 0.0012 - val_loss: 0.0073
# Epoch 12/150
# 64/64 [==============================] - 11s 177ms/step - loss: 0.0012 - val_loss: 0.0057
# Epoch 13/150
# 64/64 [==============================] - 11s 170ms/step - loss: 0.0011 - val_loss: 0.0063
# Epoch 14/150
# 64/64 [==============================] - 16s 250ms/step - loss: 0.0011 - val_loss: 0.0028
# Epoch 15/150
# 64/64 [==============================] - 13s 212ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 16/150
# 64/64 [==============================] - 7s 113ms/step - loss: 9.9157e-04 - val_loss: 0.0043
# Epoch 17/150
# 64/64 [==============================] - 7s 112ms/step - loss: 9.3540e-04 - val_loss: 0.0020
# Epoch 18/150
# 64/64 [==============================] - 7s 106ms/step - loss: 8.9901e-04 - val_loss: 0.0013
# Epoch 19/150
# 64/64 [==============================] - 7s 116ms/step - loss: 8.3851e-04 - val_loss: 0.0013
# Epoch 20/150
# 64/64 [==============================] - 6s 96ms/step - loss: 7.8714e-04 - val_loss: 0.0013
# Epoch 21/150
# 64/64 [==============================] - 8s 124ms/step - loss: 7.7884e-04 - val_loss: 0.0012
# Epoch 22/150
# 64/64 [==============================] - 6s 95ms/step - loss: 7.8303e-04 - val_loss: 8.7786e-04
# Epoch 23/150
# 64/64 [==============================] - 8s 126ms/step - loss: 7.8474e-04 - val_loss: 0.0035
# Epoch 24/150
# 64/64 [==============================] - 6s 94ms/step - loss: 7.0299e-04 - val_loss: 0.0014
# Epoch 25/150
# 64/64 [==============================] - 8s 127ms/step - loss: 6.8281e-04 - val_loss: 0.0024
# Epoch 26/150
# 64/64 [==============================] - 6s 94ms/step - loss: 6.9136e-04 - val_loss: 0.0038
# Epoch 27/150
# 64/64 [==============================] - 9s 138ms/step - loss: 6.6140e-04 - val_loss: 7.1605e-04
# Epoch 28/150
# 64/64 [==============================] - 6s 93ms/step - loss: 6.6930e-04 - val_loss: 7.8722e-04
# Epoch 29/150
# 64/64 [==============================] - 8s 124ms/step - loss: 6.3987e-04 - val_loss: 6.3241e-04
# Epoch 30/150
# 64/64 [==============================] - 6s 97ms/step - loss: 5.9397e-04 - val_loss: 0.0025
# Epoch 31/150
# 64/64 [==============================] - 7s 111ms/step - loss: 6.2892e-04 - val_loss: 5.6641e-04
# Epoch 32/150
# 64/64 [==============================] - 7s 108ms/step - loss: 5.9607e-04 - val_loss: 0.0023
# Epoch 33/150
# 64/64 [==============================] - 7s 103ms/step - loss: 5.6758e-04 - val_loss: 6.1240e-04
# Epoch 34/150
# 64/64 [==============================] - 8s 119ms/step - loss: 6.3068e-04 - val_loss: 0.0021
# Epoch 35/150
# 64/64 [==============================] - 6s 94ms/step - loss: 5.5295e-04 - val_loss: 5.6032e-04
# Epoch 36/150
# 64/64 [==============================] - 8s 124ms/step - loss: 5.8180e-04 - val_loss: 0.0012
# Epoch 37/150
# 64/64 [==============================] - 6s 95ms/step - loss: 5.5999e-04 - val_loss: 9.9348e-04
# Epoch 38/150
# 64/64 [==============================] - 8s 126ms/step - loss: 5.4069e-04 - val_loss: 6.1624e-04
# Epoch 39/150
# 64/64 [==============================] - 6s 97ms/step - loss: 5.3997e-04 - val_loss: 7.0260e-04
# Epoch 40/150
# 64/64 [==============================] - 8s 128ms/step - loss: 5.1861e-04 - val_loss: 6.0622e-04
# Epoch 41/150
# 64/64 [==============================] - 6s 95ms/step - loss: 5.4894e-04 - val_loss: 0.0022
# Epoch 42/150
# 64/64 [==============================] - 9s 143ms/step - loss: 5.0248e-04 - val_loss: 8.9012e-04
# Epoch 43/150
# 64/64 [==============================] - 6s 95ms/step - loss: 5.0789e-04 - val_loss: 8.6684e-04
# Epoch 44/150
# 64/64 [==============================] - 8s 123ms/step - loss: 4.9734e-04 - val_loss: 8.1679e-04
# Epoch 45/150
# 64/64 [==============================] - 6s 98ms/step - loss: 4.9523e-04 - val_loss: 5.5066e-04
# Epoch 46/150
# 64/64 [==============================] - 7s 111ms/step - loss: 5.2999e-04 - val_loss: 0.0019
# Epoch 47/150
# 64/64 [==============================] - 8s 121ms/step - loss: 4.9425e-04 - val_loss: 6.5621e-04
# Epoch 48/150
# 64/64 [==============================] - 7s 111ms/step - loss: 4.9644e-04 - val_loss: 0.0018
# Epoch 49/150
# 64/64 [==============================] - 7s 114ms/step - loss: 4.5763e-04 - val_loss: 0.0020
# Epoch 50/150
# 64/64 [==============================] - 6s 100ms/step - loss: 5.3128e-04 - val_loss: 7.2920e-04
# Epoch 51/150
# 64/64 [==============================] - 8s 126ms/step - loss: 4.4811e-04 - val_loss: 9.0751e-04
# Epoch 52/150
# 64/64 [==============================] - 6s 96ms/step - loss: 4.5195e-04 - val_loss: 5.9325e-04
# Epoch 53/150
# 64/64 [==============================] - 8s 130ms/step - loss: 4.6216e-04 - val_loss: 6.9823e-04
# Epoch 81/150
# 64/64 [==============================] - 8s 126ms/step - loss: 3.9079e-04 - val_loss: 0.0021
# Epoch 82/150
# 64/64 [==============================] - 6s 96ms/step - loss: 4.0266e-04 - val_loss: 0.0026
# Epoch 83/150
# 64/64 [==============================] - 8s 125ms/step - loss: 3.5735e-04 - val_loss: 0.0011
# Epoch 84/150
# 64/64 [==============================] - 6s 95ms/step - loss: 3.6518e-04 - val_loss: 6.9518e-04
# Epoch 85/150
# 64/64 [==============================] - 8s 128ms/step - loss: 3.4072e-04 - val_loss: 5.8317e-04
# Epoch 86/150
# 64/64 [==============================] - 6s 95ms/step - loss: 3.7230e-04 - val_loss: 7.3647e-04
# Epoch 87/150
# 64/64 [==============================] - 8s 128ms/step - loss: 3.5338e-04 - val_loss: 0.0019
# Epoch 88/150
# 64/64 [==============================] - 6s 93ms/step - loss: 3.6155e-04 - val_loss: 0.0012
# Epoch 89/150
# 64/64 [==============================] - 8s 121ms/step - loss: 3.7121e-04 - val_loss: 0.0012
# Epoch 90/150
# 64/64 [==============================] - 6s 100ms/step - loss: 3.3381e-04 - val_loss: 0.0011
# Epoch 91/150
# 64/64 [==============================] - 7s 110ms/step - loss: 3.5188e-04 - val_loss: 0.0022
# Epoch 92/150
# 64/64 [==============================] - 7s 109ms/step - loss: 3.7245e-04 - val_loss: 0.0016
# Epoch 93/150
# 64/64 [==============================] - 7s 104ms/step - loss: 3.3635e-04 - val_loss: 0.0026
# Epoch 94/150
# 64/64 [==============================] - 8s 122ms/step - loss: 3.4511e-04 - val_loss: 9.6339e-04
# Epoch 95/150
# 64/64 [==============================] - 6s 96ms/step - loss: 3.4828e-04 - val_loss: 0.0018
# Epoch 96/150
# 64/64 [==============================] - 8s 127ms/step - loss: 3.4079e-04 - val_loss: 8.2687e-04
# Epoch 97/150
# 64/64 [==============================] - 6s 95ms/step - loss: 3.5380e-04 - val_loss: 8.6516e-04
# Epoch 98/150
# 64/64 [==============================] - 8s 128ms/step - loss: 3.2928e-04 - val_loss: 0.0016
# Epoch 99/150
# 64/64 [==============================] - 6s 96ms/step - loss: 3.5319e-04 - val_loss: 9.3931e-04
# Epoch 100/150
# 64/64 [==============================] - 8s 125ms/step - loss: 3.3479e-04 - val_loss: 0.0035
# Epoch 101/150
# 64/64 [==============================] - 6s 95ms/step - loss: 3.9521e-04 - val_loss: 9.7276e-04
# Epoch 102/150
# 64/64 [==============================] - 8s 129ms/step - loss: 3.6512e-04 - val_loss: 0.0018
# Epoch 103/150
# 64/64 [==============================] - 6s 94ms/step - loss: 3.6652e-04 - val_loss: 9.3804e-04
# Epoch 104/150
# 64/64 [==============================] - 8s 119ms/step - loss: 3.4525e-04 - val_loss: 6.9566e-04
# Epoch 105/150
# 64/64 [==============================] - 6s 100ms/step - loss: 3.2595e-04 - val_loss: 7.9883e-04
# Epoch 106/150
# 64/64 [==============================] - 7s 108ms/step - loss: 3.2365e-04 - val_loss: 7.1161e-04
# Epoch 107/150
# 64/64 [==============================] - 7s 115ms/step - loss: 5.3279e-04 - val_loss: 7.3225e-04
# Epoch 108/150
# 64/64 [==============================] - 6s 98ms/step - loss: 3.8045e-04 - val_loss: 5.1219e-04
# Epoch 109/150
# 64/64 [==============================] - 8s 122ms/step - loss: 3.7752e-04 - val_loss: 9.2039e-04
# Epoch 110/150
# 64/64 [==============================] - 6s 95ms/step - loss: 3.3585e-04 - val_loss: 5.6952e-04
# Epoch 111/150
# 64/64 [==============================] - 8s 129ms/step - loss: 3.5351e-04 - val_loss: 7.4848e-04
# Epoch 112/150
# 64/64 [==============================] - 6s 95ms/step - loss: 3.4798e-04 - val_loss: 0.0011
# Epoch 113/150
# 64/64 [==============================] - 8s 126ms/step - loss: 3.2456e-04 - val_loss: 6.9491e-04
# Epoch 114/150
# 64/64 [==============================] - 6s 95ms/step - loss: 3.4123e-04 - val_loss: 7.4851e-04
# Epoch 115/150
# 64/64 [==============================] - 8s 127ms/step - loss: 3.1419e-04 - val_loss: 4.7019e-04
# Epoch 116/150
# 64/64 [==============================] - 6s 95ms/step - loss: 3.4413e-04 - val_loss: 4.9462e-04
# Epoch 117/150
# 64/64 [==============================] - 8s 125ms/step - loss: 3.3184e-04 - val_loss: 5.9313e-04
# Epoch 118/150
# 64/64 [==============================] - 6s 95ms/step - loss: 3.4948e-04 - val_loss: 7.8718e-04
# Epoch 119/150
# 64/64 [==============================] - 8s 120ms/step - loss: 3.3594e-04 - val_loss: 0.0012
# Epoch 120/150
# 64/64 [==============================] - 7s 104ms/step - loss: 3.2029e-04 - val_loss: 0.0016
# Epoch 121/150
# 64/64 [==============================] - 7s 110ms/step - loss: 3.1391e-04 - val_loss: 5.0268e-04
# Epoch 122/150
# 64/64 [==============================] - 7s 115ms/step - loss: 3.2175e-04 - val_loss: 8.2957e-04
# Epoch 123/150
# 64/64 [==============================] - 7s 103ms/step - loss: 3.0980e-04 - val_loss: 0.0017
# Epoch 124/150
# 64/64 [==============================] - 8s 119ms/step - loss: 3.1472e-04 - val_loss: 0.0011
# Epoch 125/150
# 64/64 [==============================] - 6s 96ms/step - loss: 3.2045e-04 - val_loss: 0.0019
# Epoch 126/150
# 64/64 [==============================] - 8s 127ms/step - loss: 3.1353e-04 - val_loss: 0.0012
# Epoch 127/150
# 64/64 [==============================] - 6s 98ms/step - loss: 3.2174e-04 - val_loss: 0.0013
# Epoch 128/150
# 64/64 [==============================] - 8s 129ms/step - loss: 3.2618e-04 - val_loss: 8.2909e-04
# Epoch 129/150
# 64/64 [==============================] - 6s 96ms/step - loss: 3.2168e-04 - val_loss: 0.0012
# Epoch 130/150
# 64/64 [==============================] - 8s 128ms/step - loss: 3.1238e-04 - val_loss: 0.0017
# Epoch 131/150
# 64/64 [==============================] - 6s 97ms/step - loss: 3.0698e-04 - val_loss: 0.0022
# Epoch 132/150
# 64/64 [==============================] - 8s 126ms/step - loss: 2.9060e-04 - val_loss: 0.0013
# Epoch 133/150
# 64/64 [==============================] - 6s 95ms/step - loss: 3.2174e-04 - val_loss: 9.8121e-04
# Epoch 134/150
# 64/64 [==============================] - 8s 131ms/step - loss: 3.1677e-04 - val_loss: 0.0031
# Epoch 135/150
# 64/64 [==============================] - 6s 95ms/step - loss: 3.0637e-04 - val_loss: 8.1242e-04
# Epoch 136/150
# 64/64 [==============================] - 8s 124ms/step - loss: 2.9610e-04 - val_loss: 0.0014
# Epoch 137/150
# 64/64 [==============================] - 6s 96ms/step - loss: 3.1531e-04 - val_loss: 0.0016
# Epoch 138/150
# 64/64 [==============================] - 8s 119ms/step - loss: 2.7833e-04 - val_loss: 9.7507e-04
# Epoch 139/150
# 64/64 [==============================] - 7s 107ms/step - loss: 3.2154e-04 - val_loss: 8.6627e-04
# Epoch 140/150
# 64/64 [==============================] - 7s 114ms/step - loss: 3.0858e-04 - val_loss: 0.0014
# Epoch 141/150
# 64/64 [==============================] - 7s 113ms/step - loss: 2.9106e-04 - val_loss: 0.0013
# Epoch 142/150
# 64/64 [==============================] - 7s 103ms/step - loss: 3.0478e-04 - val_loss: 0.0012
# Epoch 143/150
# 64/64 [==============================] - 8s 122ms/step - loss: 3.0147e-04 - val_loss: 0.0015
# Epoch 144/150
# 64/64 [==============================] - 6s 97ms/step - loss: 2.9782e-04 - val_loss: 0.0024
# Epoch 145/150
# 64/64 [==============================] - 8s 130ms/step - loss: 2.8733e-04 - val_loss: 0.0010
# Epoch 146/150
# 64/64 [==============================] - 6s 97ms/step - loss: 3.0396e-04 - val_loss: 0.0017
# Epoch 147/150
# 64/64 [==============================] - 8s 130ms/step - loss: 3.0336e-04 - val_loss: 7.3107e-04
# Epoch 148/150
# 64/64 [==============================] - 6s 96ms/step - loss: 2.8322e-04 - val_loss: 0.0013
# Epoch 149/150
# 64/64 [==============================] - 8s 131ms/step - loss: 3.0419e-04 - val_loss: 0.0013
# Epoch 150/150
# 64/64 [==============================] - 6s 98ms/step - loss: 3.0533e-04 - val_loss: 0.0018

# %%
result = model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)
# Out:
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0014
# 9/9 [==============================] - 1s 26ms/step

# %%
MAPE = mean_absolute_percentage_error(y_test, y_pred)
Accuracy = 1 - MAPE

# %%
print("Test Loss:", result)
print("Test MAPE:", MAPE)
print("Test Accuracy:", Accuracy)
# Out:
# Test Loss: 0.001363303977996111
# Test MAPE: 0.0416968620265665
# Test Accuracy: 0.9583031379734335

# %%
y_test_true = scaler.inverse_transform(y_test)
y_test_pred = scaler.inverse_transform(y_pred)

# %%
plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'yellow'
plt.rc('axes',edgecolor='white')
plt.plot(df['Date'].iloc[:-test_size], scaler.inverse_transform(train_data), color='black', lw=2)
plt.plot(df['Date'].iloc[-test_size:], y_test_true, color='blue', lw=2)
plt.plot(df['Date'].iloc[-test_size:], y_test_pred, color='red', lw=2)
plt.title('Model Performance on Gold Price Prediction', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.legend(['Training Data', 'Actual Test Data', 'Predicted Test Data'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()
